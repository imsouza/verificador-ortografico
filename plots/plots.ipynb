# %%
import matplotlib.pyplot as plt
import numpy
# %matplotlib inline

# %%
"""
segundosABB_1 = [29.1247270000, 1294.286984000]
segundosABB_2 = [7.71338800000, 2432.797850000]
segundosABB_3 = [39.0822060000, 2510.467780000]

segundosAVL_1 = [1.23397700000, 2.58426400000]
segundosAVL_2 = [0.30257700000, 2.87204600000]
segundosAVL_3 = [6.11318400000, 22.8842430000]
"""
"""
segundosAVL_EN_1 = [0.09121100000, 1.21719700000]
segundosAVL_EN_2 = [0.18262300000, 0.79505800000]
segundosAVL_EN_3 = [0.54253900000, 2.86762000000]
"""
segundosABB_EN_1 = [0.83884000000, 527.609602000]
segundosABB_EN_2 = [0.89706200000, 590.016500000]
segundosABB_EN_3 = [1.39018000000, 582.442895000]


#dicionariosPtBR = [28637, 261801]
dicionariosEnUS = [10000,118467]

plt.figure(figsize=(10, 5))

plt.title('Gráfico do tempo de execução da ABB para dicionários em en-US')
plt.xlabel('Tempo de Execução em Segundos')
plt.ylabel('Tamanho do Dicionário')

"""
plt.bar(segundosABB_1, dicionariosPtBR, color='red', width=10)
plt.bar(segundosABB_2, dicionariosPtBR, color='blue', width=10)
plt.bar(segundosABB_3, dicionariosPtBR, color='orange', width=10)

plt.bar(segundosAVL_1, dicionariosPtBR, color='#6A5ACD', width=10)
plt.bar(segundosAVL_2, dicionariosPtBR, color='#6495ED', width=10)
plt.bar(segundosAVL_3, dicionariosPtBR, color='#00BFFF', width=10)
"""
"""
plt.bar(segundosAVL_EN_1, dicionariosEnUS, color='green', width=0.2)
plt.bar(segundosAVL_EN_2, dicionariosEnUS, color='grey', width=0.2)
plt.bar(segundosAVL_EN_3, dicionariosEnUS, color='yellow', width=0.2)
"""

plt.bar(segundosABB_EN_1, dicionariosEnUS, color='#852600', width=5)
plt.bar(segundosABB_EN_2, dicionariosEnUS, color='#e800c9', width=5)
plt.bar(segundosABB_EN_3, dicionariosEnUS, color='#d1b33d', width=5)

plt.legend(('80 palavras', '9 palavras', '269 palavras'))

plt.show()
